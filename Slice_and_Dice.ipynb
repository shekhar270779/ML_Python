# %% [markdown]
# ## Slicing and Dicing

# %% [markdown]
# <p>In data analysis, the term <b> slicing and dicing </b> generally implies a systematic method of reducing a complete set of data into smaller parts or views that will help to yield more information.</p>
# <p> In this notebook we will be performing common operations related to slicing and dicing</p>

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.0.3

# %%
# Import dataset
wine_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')

# %%
wine_df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %% [markdown]
# <p>We have imported <b>Wine Quality Dataset </b>hosted on the UCI website. This data record 11 chemical properties (such as the concentrations of sugar, citric acid, alcohol, pH etc.) of thousands of red and white wines from northern Portugal, as well as the quality of the wines, recorded on a scale from 1 to 10. <p>
# We will only look at the data for red wine

# %% [markdown]
# <h4> Replace all spaces with underscores in column header </h4>

# %%
wine_df.columns = wine_df.columns.str.replace(' ','_')

# %%
wine_df.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %% [markdown]
# <h4> Select data from specific column </h4>

# %%
# select fixed_acidity column data
wine_df['fixed_acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed_acidity, Length: 1599, dtype: float64

# %% [markdown]
# <h4>Select column Using dot notation</h4>

# %%
wine_df.fixed_acidity
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed_acidity, Length: 1599, dtype: float64

# %% [markdown]
# <p><b> Above two methods return data in form of pandas.Series </b></p>
# <h4>To select single column data as a DataFrame, place column name inside double brackets, as below</h4>

# %%
wine_df[['fixed_acidity']]
# Out:
#       fixed_acidity
# 0               7.4
# 1               7.8
# 2               7.8
# 3              11.2
# 4               7.4
# ...             ...
# 1594            6.2
# 1595            5.9
# 1596            6.3
# 1597            5.9
# 1598            6.0
#
# [1599 rows x 1 columns]

# %% [markdown]
# <h4> Select multiple columns </h4>

# %%
cols = ['fixed_acidity', 'volatile_acidity','citric_acid', 'residual_sugar']
wine_df[cols].head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# 0            7.4              0.70         0.00             1.9
# 1            7.8              0.88         0.00             2.6
# 2            7.8              0.76         0.04             2.3
# 3           11.2              0.28         0.56             1.9
# 4            7.4              0.70         0.00             1.9

# %% [markdown]
# <h4>Select columns based on datatypes </h4>

# %%
# First lets see what is datatype of all columns
wine_df.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# select all float type columns
wine_df.select_dtypes(include='float').head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %% [markdown]
# <h4>Select columns based on specific labels </h4>

# %%
# select all columns which have 'acid' in column name
wine_df.filter(like='acid').head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid
# 0            7.4              0.70         0.00
# 1            7.8              0.88         0.00
# 2            7.8              0.76         0.04
# 3           11.2              0.28         0.56
# 4            7.4              0.70         0.00

# %%
<b>This returns columns which have acidity and acid both</b>

# %% [markdown]
# <b>Suppose we want to select only that columns which end with 'acid', we can use regex form as following</b>

# %%
wine_df.filter(regex='acid$').head()
# Out:
#    citric_acid
# 0         0.00
# 1         0.00
# 2         0.04
# 3         0.56
# 4         0.00

# %% [markdown]
# <h4>Rename a column name </h4>

# %%
wine_df.rename(columns = {'pH': 'pH_5'}, inplace=True)

# %% [markdown]
# <h4>Select only those columns which have a digit in name</h4>

# %%
wine_df.filter(regex='\d').head()
# Out:
#    pH_5
# 0  3.51
# 1  3.20
# 2  3.26
# 3  3.16
# 4  3.51

# %% [markdown]
# <h4> Select rows and columns using iloc and loc </h4>

# %% [markdown]
# * iloc is used to select based on numeric index of rows and columns
# * loc is used to select rows and columns based on labels

# %% [markdown]
# <h4>iloc examples </h4>

# %%
# select first 3 rows i.e index 0 to 2
wine_df.iloc[0:3]
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density  pH_5  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
# select first 3 rows and first five columns
wine_df.iloc[0:3, 0:5]
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092

# %%
# select last 3 rows and last 2 columns
wine_df.iloc[-3:, -2:]
# Out:
#       alcohol  quality
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %% [markdown]
# <h4>loc examples </h4>

# %%
# select first 3 rows specific columns 
wine_df.loc[0:2, ['alcohol', 'pH_5', 'quality']]
# Out:
#    alcohol  pH_5  quality
# 0      9.4  3.51        5
# 1      9.8  3.20        5
# 2      9.8  3.26        5

# %% [markdown]
# <h4> Set new index </h4>

# %%
# Set density as index 
wine_df.set_index('density', inplace=True)

# %%
wine_df.head(3)
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# density
# 0.9978             7.4              0.70         0.00             1.9
# 0.9968             7.8              0.88         0.00             2.6
# 0.9970             7.8              0.76         0.04             2.3
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide  pH_5  \
# density
# 0.9978       0.076                 11.0                  34.0  3.51
# 0.9968       0.098                 25.0                  67.0  3.20
# 0.9970       0.092                 15.0                  54.0  3.26
#
#          sulphates  alcohol  quality
# density
# 0.9978        0.56      9.4        5
# 0.9968        0.68      9.8        5
# 0.9970        0.65      9.8        5

# %% [markdown]
# <h4> Select records of specific density</h4>

# %%
wine_df.loc[0.9968].head()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# density
# 0.9968             7.8              0.88         0.00             2.6
# 0.9968             7.8              0.58         0.02             2.0
# 0.9968             8.1              0.56         0.28             1.7
# 0.9968             8.9              0.22         0.48             1.8
# 0.9968             8.5              0.49         0.11             2.3
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide  pH_5  \
# density
# 0.9968       0.098                 25.0                  67.0  3.20
# 0.9968       0.073                  9.0                  18.0  3.36
# 0.9968       0.368                 16.0                  56.0  3.11
# 0.9968       0.077                 29.0                  60.0  3.39
# 0.9968       0.084                  9.0                  67.0  3.17
#
#          sulphates  alcohol  quality
# density
# 0.9968        0.68      9.8        5
# 0.9968        0.57      9.5        7
# 0.9968        1.28      9.3        5
# 0.9968        0.53      9.4        6
# 0.9968        0.53      9.4        5

# %% [markdown]
# <h4>select subset of columns for records of a specific density </h4>

# %%
wine_df.loc[0.9968, ['alcohol', 'quality']].head()
# Out:
#          alcohol  quality
# density
# 0.9968       9.8        5
# 0.9968       9.5        7
# 0.9968       9.3        5
# 0.9968       9.4        6
# 0.9968       9.4        5

# %% [markdown]
# <h4> Reset index </h4>

# %%
wine_df.reset_index(inplace=True)

# %%
wine_df.head(3)
# Out:
#    density  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0   0.9978            7.4              0.70         0.00             1.9
# 1   0.9968            7.8              0.88         0.00             2.6
# 2   0.9970            7.8              0.76         0.04             2.3
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  pH_5  sulphates  \
# 0      0.076                 11.0                  34.0  3.51       0.56
# 1      0.098                 25.0                  67.0  3.20       0.68
# 2      0.092                 15.0                  54.0  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %% [markdown]
# <b> when index is reset, it gets added as first column be default </b>

# %% [markdown]
# <h4>Filter records based on some logical conditions</h4>

# %%
# Select records based on two conditions as below
cond1 = wine_df['density'] ==0.9968

cond2 = wine_df['alcohol'] >=10

wine_df[cond1 & cond2].head()
# Out:
#     density  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 7    0.9968            7.3             0.650         0.00             1.2
# 9    0.9968            7.5             0.500         0.36             6.1
# 11   0.9968            7.5             0.500         0.36             6.1
# 16   0.9968            8.5             0.280         0.56             1.8
# 30   0.9968            6.7             0.675         0.07             2.4
#
#     chlorides  free_sulfur_dioxide  total_sulfur_dioxide  pH_5  sulphates  \
# 7       0.065                 15.0                  21.0  3.39       0.47
# 9       0.071                 17.0                 102.0  3.35       0.80
# 11      0.071                 17.0                 102.0  3.35       0.80
# 16      0.092                 35.0                 103.0  3.30       0.75
# 30      0.089                 17.0                  82.0  3.35       0.54
#
#     alcohol  quality
# 7      10.0        7
# 9      10.5        5
# 11     10.5        5
# 16     10.5        7
# 30     10.1        5

# %% [markdown]
# ### Additional examples

# %%
df = pd.DataFrame({'x':[1,5,4,3,4,5],
  'y':[.1,.5,.4,.3,.4,.5],
'w':[11,15,14,13,14,15]})

df
# Out:
#    x    y   w
# 0  1  0.1  11
# 1  5  0.5  15
# 2  4  0.4  14
# 3  3  0.3  13
# 4  4  0.4  14
# 5  5  0.5  15

# %%
df.loc[df['x']> 3, 'y'] = 50

# %%
df
# Out:
#    x     y   w
# 0  1   0.1  11
# 1  5  50.0  15
# 2  4  50.0  14
# 3  3   0.3  13
# 4  4  50.0  14
# 5  5  50.0  15

# %%
df = pd.DataFrame({'x':[1,5,4,3,4,5],
  'y':[.1,.5,.4,.3,.4,.5],
'w':[11,15,14,13,14,15]})

df
# Out:
#    x    y   w
# 0  1  0.1  11
# 1  5  0.5  15
# 2  4  0.4  14
# 3  3  0.3  13
# 4  4  0.4  14
# 5  5  0.5  15

# %%
df[df['x']>3]['y'] = 50
# Out:
# C:\Users\Shekhar2707\Anaconda3_5\envs\test_env_3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#    x    y   w
# 0  1  0.1  11
# 1  5  0.5  15
# 2  4  0.4  14
# 3  3  0.3  13
# 4  4  0.4  14
# 5  5  0.5  15
